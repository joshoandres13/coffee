# %% [markdown]
# ### Who drinks more coffee on average: Europeans or Americans?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px  #with anaconda3

# %%
df_domestic = pd.read_csv("dataset/Coffee_domestic_consumption.csv", sep=",")
df_domestic.head(55)
# Out:
#                              Country      Coffee type    1990/91    1991/92  \
# 0                             Angola  Robusta/Arabica    1200000    1800000
# 1   Bolivia (Plurinational State of)          Arabica    1500000    1620000
# 2                             Brazil  Arabica/Robusta  492000000  510000000
# 3                            Burundi  Arabica/Robusta     120000      96000
# 4                            Ecuador  Arabica/Robusta   21000000   21000000
# 5                          Indonesia  Robusta/Arabica   74520000   76800000
# 6                         Madagascar          Robusta   21000000   18000000
# 7                             Malawi          Arabica     120000     120000
# 8                   Papua New Guinea  Arabica/Robusta     180000     180000
# 9                           Paraguay          Arabica     900000     900000
# 10                              Peru          Arabica   11400000   11400000
# ...

# %%
df_importers = pd.read_csv("dataset/Coffee_importers_consumption.csv", sep=",")
df_importers.head(55)
# Out:
#                      Country        1990        1991        1992        1993  \
# 0                    Austria    80400000    78120000    72720000    80100000
# 1                    Belgium           0           0           0           0
# 2         Belgium/Luxembourg    67440000    42480000    41760000    47340000
# 3                   Bulgaria     6120000     1020000    10500000    19620000
# 4                    Croatia           0           0     8100000     7920000
# 5                     Cyprus     1860000     2700000     2340000     4680000
# 6                    Czechia    39540000    31500000    28320000    26880000
# 7                    Denmark    51900000    54540000    57540000    53460000
# 8                    Estonia           0           0      780000     2640000
# 9                    Finland    64200000    57960000    61800000    67740000
# 10                    France   312300000   333420000   336840000   330420000
# ...

# %%
Europe = df.iloc[[]]  # Primera, tercera y segunda filas
America = df.iloc[[1,2,4,9,10,15,23,24,27,32,34,35,41,43,45,50,52]]  # Primera, tercera y segunda filas
